# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pickle as pkl

# %% [markdown]
# ## ____________________________________________________________________

# %% [markdown]
# ## Import Datasets

# %%
# import fifa_worldcup_2022_groupstages.csv
df = pd.read_csv('/Users/yenhann/Documents/MIT/15.095 Machine Learning/15095-project/data/fifa_worldcup_2022_groupstages.csv')

# create an empty dataframe with the same column names as df
knockout_stages = pd.DataFrame(columns=df.columns)

# drop group column from knockout_stages
knockout_stages = knockout_stages.drop(columns=['group'])

# # MATCH 1 : NETHERLANDS v. USA ---------------------------------------------------------------------------------
date = '2022-12-03'
home_team = 'Netherlands'
away_team = 'USA'
home_team_continent = 'Europe'
away_team_continent = 'North America'
tournament = 'FIFA World Cup'
city = 'Al Rayyan'
country = 'Qatar'
neutral_location = 'False'

# find rows where netherlands is home team and take the home_team_fifa_ranking
home_team_rank = df[df['home_team'] == home_team]['home_team_fifa_rank'].values[0]
home_team_total_fifa_points = df[df['home_team'] == home_team]['home_team_total_fifa_points'].values[0]
home_team_goalkeeper_score = df[df['home_team'] == home_team]['home_team_goalkeeper_score'].values[0]
home_team_mean_defense_score = df[df['home_team'] == home_team]['home_team_mean_defense_score'].values[0]
home_team_mean_midfield_score = df[df['home_team'] == home_team]['home_team_mean_midfield_score'].values[0]
home_team_mean_offense_score = df[df['home_team'] == home_team]['home_team_mean_offense_score'].values[0]

# find rows where usa is away team and take the away_team_fifa_ranking
away_team_rank = df[df['away_team'] == away_team]['away_team_fifa_rank'].values[0]
away_team_total_fifa_points = df[df['away_team'] == away_team]['away_team_total_fifa_points'].values[0]
away_team_goalkeeper_score = df[df['away_team'] == away_team]['away_team_goalkeeper_score'].values[0]
away_team_mean_defense_score = df[df['away_team'] == away_team]['away_team_mean_defense_score'].values[0]
away_team_mean_midfield_score = df[df['away_team'] == away_team]['away_team_mean_midfield_score'].values[0]
away_team_mean_offense_score = df[df['away_team'] == away_team]['away_team_mean_offense_score'].values[0]

# add a row to knockout_stages
knockout_stages = knockout_stages.append({'date': date, 'home_team': home_team, 'away_team': away_team, 
                                          'home_team_continent': home_team_continent, 'away_team_continent': away_team_continent, 
                                          'tournament': tournament, 'city': city, 'country': country, 'neutral_location': neutral_location, 
                                          'home_team_fifa_rank': home_team_rank, 'home_team_total_fifa_points': home_team_total_fifa_points, 
                                          'home_team_goalkeeper_score': home_team_goalkeeper_score, 'home_team_mean_defense_score': home_team_mean_defense_score, 
                                          'home_team_mean_midfield_score': home_team_mean_midfield_score, 'home_team_mean_offense_score': home_team_mean_offense_score, 
                                          'away_team_fifa_rank': away_team_rank, 'away_team_total_fifa_points': away_team_total_fifa_points, 
                                          'away_team_goalkeeper_score': away_team_goalkeeper_score, 'away_team_mean_defense_score': away_team_mean_defense_score, 
                                          'away_team_mean_midfield_score': away_team_mean_midfield_score, 'away_team_mean_offense_score': away_team_mean_offense_score}, 
                                          ignore_index=True)

# # MATCH 1 : NETHERLANDS v. USA ---------------------------------------------------------------------------------

# # -----------------------------------------------------------------------------------------------------------------------------

# # MATCH 2 : ARGENTINA V. AUSTRALIA ---------------------------------------------------------------------------------
date = '2022-12-03'
home_team = 'Argentina'
away_team = 'Australia'
home_team_continent = 'South America'
away_team_continent = 'Oceania'
tournament = 'FIFA World Cup'
city = 'Al Rayyan'
country = 'Qatar'
neutral_location = 'False'

# find rows where argentina is home team and take the home_team_fifa_ranking
home_team_rank = df[df['home_team'] == home_team]['home_team_fifa_rank'].values[0]
home_team_total_fifa_points = df[df['home_team'] == home_team]['home_team_total_fifa_points'].values[0]
home_team_goalkeeper_score = df[df['home_team'] == home_team]['home_team_goalkeeper_score'].values[0]
home_team_mean_defense_score = df[df['home_team'] == home_team]['home_team_mean_defense_score'].values[0]
home_team_mean_midfield_score = df[df['home_team'] == home_team]['home_team_mean_midfield_score'].values[0]
home_team_mean_offense_score = df[df['home_team'] == home_team]['home_team_mean_offense_score'].values[0]

# find rows where australia is away team and take the away_team_fifa_ranking
away_team_rank = df[df['away_team'] == away_team]['away_team_fifa_rank'].values[0]
away_team_total_fifa_points = df[df['away_team'] == away_team]['away_team_total_fifa_points'].values[0]
away_team_goalkeeper_score = df[df['away_team'] == away_team]['away_team_goalkeeper_score'].values[0]
away_team_mean_defense_score = df[df['away_team'] == away_team]['away_team_mean_defense_score'].values[0]
away_team_mean_midfield_score = df[df['away_team'] == away_team]['away_team_mean_midfield_score'].values[0]
away_team_mean_offense_score = df[df['away_team'] == away_team]['away_team_mean_offense_score'].values[0]

# add a row to knockout_stages
knockout_stages = knockout_stages.append({'date': date, 'home_team': home_team, 'away_team': away_team,
                                          'home_team_continent': home_team_continent, 'away_team_continent': away_team_continent,
                                          'tournament': tournament, 'city': city, 'country': country, 'neutral_location': neutral_location,
                                          'home_team_fifa_rank': home_team_rank, 'home_team_total_fifa_points': home_team_total_fifa_points,
                                          'home_team_goalkeeper_score': home_team_goalkeeper_score, 'home_team_mean_defense_score': home_team_mean_defense_score,
                                          'home_team_mean_midfield_score': home_team_mean_midfield_score, 'home_team_mean_offense_score': home_team_mean_offense_score,
                                          'away_team_fifa_rank': away_team_rank, 'away_team_total_fifa_points': away_team_total_fifa_points,
                                          'away_team_goalkeeper_score': away_team_goalkeeper_score, 'away_team_mean_defense_score': away_team_mean_defense_score,
                                          'away_team_mean_midfield_score': away_team_mean_midfield_score, 'away_team_mean_offense_score': away_team_mean_offense_score},
                                          ignore_index=True)
# # MATCH 2 : ARGENTINA V. AUSTRALIA ---------------------------------------------------------------------------------

# # -----------------------------------------------------------------------------------------------------------------------------

# # MATCH 3 : FRANCE V. POLAND ---------------------------------------------------------------------------------
date = '2022-12-04'
home_team = 'France'
away_team = 'Poland'
home_team_continent = 'Europe'
away_team_continent = 'Europe'
tournament = 'FIFA World Cup'
city = 'Doha'
country = 'Qatar'
neutral_location = 'False'

# find rows where france is home team and take the home_team_fifa_ranking
home_team_rank = df[df['home_team'] == home_team]['home_team_fifa_rank'].values[0]
home_team_total_fifa_points = df[df['home_team'] == home_team]['home_team_total_fifa_points'].values[0]
home_team_goalkeeper_score = df[df['home_team'] == home_team]['home_team_goalkeeper_score'].values[0]
home_team_mean_defense_score = df[df['home_team'] == home_team]['home_team_mean_defense_score'].values[0]
home_team_mean_midfield_score = df[df['home_team'] == home_team]['home_team_mean_midfield_score'].values[0]
home_team_mean_offense_score = df[df['home_team'] == home_team]['home_team_mean_offense_score'].values[0]

# find rows where poland is away team and take the away_team_fifa_ranking
away_team_rank = df[df['away_team'] == away_team]['away_team_fifa_rank'].values[0]
away_team_total_fifa_points = df[df['away_team'] == away_team]['away_team_total_fifa_points'].values[0]
away_team_goalkeeper_score = df[df['away_team'] == away_team]['away_team_goalkeeper_score'].values[0]
away_team_mean_defense_score = df[df['away_team'] == away_team]['away_team_mean_defense_score'].values[0]
away_team_mean_midfield_score = df[df['away_team'] == away_team]['away_team_mean_midfield_score'].values[0]
away_team_mean_offense_score = df[df['away_team'] == away_team]['away_team_mean_offense_score'].values[0]

# add a row to knockout_stages
knockout_stages = knockout_stages.append({'date': date, 'home_team': home_team, 'away_team': away_team,
                                            'home_team_continent': home_team_continent, 'away_team_continent': away_team_continent,
                                            'tournament': tournament, 'city': city, 'country': country, 'neutral_location': neutral_location,
                                            'home_team_fifa_rank': home_team_rank, 'home_team_total_fifa_points': home_team_total_fifa_points,
                                            'home_team_goalkeeper_score': home_team_goalkeeper_score, 'home_team_mean_defense_score': home_team_mean_defense_score,
                                            'home_team_mean_midfield_score': home_team_mean_midfield_score, 'home_team_mean_offense_score': home_team_mean_offense_score,
                                            'away_team_fifa_rank': away_team_rank, 'away_team_total_fifa_points': away_team_total_fifa_points,
                                            'away_team_goalkeeper_score': away_team_goalkeeper_score, 'away_team_mean_defense_score': away_team_mean_defense_score,
                                            'away_team_mean_midfield_score': away_team_mean_midfield_score, 'away_team_mean_offense_score': away_team_mean_offense_score},
                                            ignore_index=True)

# # MATCH 3 : FRANCE V. POLAND ---------------------------------------------------------------------------------

# # -----------------------------------------------------------------------------------------------------------------------------

# # MATCH 4 : ENGLAND V. SENEGAL ---------------------------------------------------------------------------------
date = '2022-12-04'
home_team = 'England'
away_team = 'Senegal'
home_team_continent = 'Europe'
away_team_continent = 'Africa'
tournament = 'FIFA World Cup'
city = 'Al Khor'
country = 'Qatar'
neutral_location = 'False'

# find rows where brazil is home team and take the home_team_fifa_ranking
home_team_rank = df[df['home_team'] == home_team]['home_team_fifa_rank'].values[0]
home_team_total_fifa_points = df[df['home_team'] == home_team]['home_team_total_fifa_points'].values[0]
home_team_goalkeeper_score = df[df['home_team'] == home_team]['home_team_goalkeeper_score'].values[0]
home_team_mean_defense_score = df[df['home_team'] == home_team]['home_team_mean_defense_score'].values[0]
home_team_mean_midfield_score = df[df['home_team'] == home_team]['home_team_mean_midfield_score'].values[0]
home_team_mean_offense_score = df[df['home_team'] == home_team]['home_team_mean_offense_score'].values[0]

# find rows where korea republic is away team and take the away_team_fifa_ranking
away_team_rank = df[df['away_team'] == away_team]['away_team_fifa_rank'].values[0]
away_team_total_fifa_points = df[df['away_team'] == away_team]['away_team_total_fifa_points'].values[0]
away_team_goalkeeper_score = df[df['away_team'] == away_team]['away_team_goalkeeper_score'].values[0]
away_team_mean_defense_score = df[df['away_team'] == away_team]['away_team_mean_defense_score'].values[0]
away_team_mean_midfield_score = df[df['away_team'] == away_team]['away_team_mean_midfield_score'].values[0]
away_team_mean_offense_score = df[df['away_team'] == away_team]['away_team_mean_offense_score'].values[0]

# add a row to knockout_stages
knockout_stages = knockout_stages.append({'date': date, 'home_team': home_team, 'away_team': away_team,
                                            'home_team_continent': home_team_continent, 'away_team_continent': away_team_continent,
                                            'tournament': tournament, 'city': city, 'country': country, 'neutral_location': neutral_location,
                                            'home_team_fifa_rank': home_team_rank, 'home_team_total_fifa_points': home_team_total_fifa_points,
                                            'home_team_goalkeeper_score': home_team_goalkeeper_score, 'home_team_mean_defense_score': home_team_mean_defense_score,
                                            'home_team_mean_midfield_score': home_team_mean_midfield_score, 'home_team_mean_offense_score': home_team_mean_offense_score,
                                            'away_team_fifa_rank': away_team_rank, 'away_team_total_fifa_points': away_team_total_fifa_points,
                                            'away_team_goalkeeper_score': away_team_goalkeeper_score, 'away_team_mean_defense_score': away_team_mean_defense_score,
                                            'away_team_mean_midfield_score': away_team_mean_midfield_score, 'away_team_mean_offense_score': away_team_mean_offense_score},
                                            ignore_index=True)

# # MATCH 4 : ENGLAND V. SENEGAL ---------------------------------------------------------------------------------

# # -----------------------------------------------------------------------------------------------------------------------------

# # MATCH 5 : JAPAN V. CROATIA ---------------------------------------------------------------------------------
date = '2022-12-05'
home_team = 'Japan'
away_team = 'Croatia'
home_team_continent = 'Asia'
away_team_continent = 'Europe'
tournament = 'FIFA World Cup'
city = 'Al Wakrah'
neutral_location = 'False'

# find rows where japan is home team and take the home_team_fifa_ranking
home_team_rank = df[df['home_team'] == home_team]['home_team_fifa_rank'].values[0]
home_team_total_fifa_points = df[df['home_team'] == home_team]['home_team_total_fifa_points'].values[0]
home_team_goalkeeper_score = df[df['home_team'] == home_team]['home_team_goalkeeper_score'].values[0]
home_team_mean_defense_score = df[df['home_team'] == home_team]['home_team_mean_defense_score'].values[0]
home_team_mean_midfield_score = df[df['home_team'] == home_team]['home_team_mean_midfield_score'].values[0]
home_team_mean_offense_score = df[df['home_team'] == home_team]['home_team_mean_offense_score'].values[0]

# find rows where korea republic is away team and take the away_team_fifa_ranking
away_team_rank = df[df['away_team'] == away_team]['away_team_fifa_rank'].values[0]
away_team_total_fifa_points = df[df['away_team'] == away_team]['away_team_total_fifa_points'].values[0]
away_team_goalkeeper_score = df[df['away_team'] == away_team]['away_team_goalkeeper_score'].values[0]
away_team_mean_defense_score = df[df['away_team'] == away_team]['away_team_mean_defense_score'].values[0]
away_team_mean_midfield_score = df[df['away_team'] == away_team]['away_team_mean_midfield_score'].values[0]
away_team_mean_offense_score = df[df['away_team'] == away_team]['away_team_mean_offense_score'].values[0]

# add a row to knockout_stages
knockout_stages = knockout_stages.append({'date': date, 'home_team': home_team, 'away_team': away_team,
                                            'home_team_continent': home_team_continent, 'away_team_continent': away_team_continent,
                                            'tournament': tournament, 'city': city, 'country': country, 'neutral_location': neutral_location,
                                            'home_team_fifa_rank': home_team_rank, 'home_team_total_fifa_points': home_team_total_fifa_points,
                                            'home_team_goalkeeper_score': home_team_goalkeeper_score, 'home_team_mean_defense_score': home_team_mean_defense_score,
                                            'home_team_mean_midfield_score': home_team_mean_midfield_score, 'home_team_mean_offense_score': home_team_mean_offense_score,
                                            'away_team_fifa_rank': away_team_rank, 'away_team_total_fifa_points': away_team_total_fifa_points,
                                            'away_team_goalkeeper_score': away_team_goalkeeper_score, 'away_team_mean_defense_score': away_team_mean_defense_score,
                                            'away_team_mean_midfield_score': away_team_mean_midfield_score, 'away_team_mean_offense_score': away_team_mean_offense_score},
                                            ignore_index=True)

# # MATCH 5 : JAPAN V. CROATIA ---------------------------------------------------------------------------------

# # -----------------------------------------------------------------------------------------------------------------------------

# # MATCH 6 : BRAZIL V. KOREA REPUBLIC ---------------------------------------------------------------------------------
date = '2022-12-05'
home_team = 'Brazil'
away_team = 'Korea Republic'
home_team_continent = 'South America'
away_team_continent = 'Asia'
tournament = 'FIFA World Cup'
city = 'Doha'
neutral_location = 'False'

# find rows where brazil is home team and take the home_team_fifa_ranking
home_team_rank = df[df['home_team'] == home_team]['home_team_fifa_rank'].values[0]
home_team_total_fifa_points = df[df['home_team'] == home_team]['home_team_total_fifa_points'].values[0]
home_team_goalkeeper_score = df[df['home_team'] == home_team]['home_team_goalkeeper_score'].values[0]
home_team_mean_defense_score = df[df['home_team'] == home_team]['home_team_mean_defense_score'].values[0]
home_team_mean_midfield_score = df[df['home_team'] == home_team]['home_team_mean_midfield_score'].values[0]
home_team_mean_offense_score = df[df['home_team'] == home_team]['home_team_mean_offense_score'].values[0]

# find rows where korea republic is away team and take the away_team_fifa_ranking
away_team_rank = df[df['away_team'] == away_team]['away_team_fifa_rank'].values[0]
away_team_total_fifa_points = df[df['away_team'] == away_team]['away_team_total_fifa_points'].values[0]
away_team_goalkeeper_score = df[df['away_team'] == away_team]['away_team_goalkeeper_score'].values[0]
away_team_mean_defense_score = df[df['away_team'] == away_team]['away_team_mean_defense_score'].values[0]
away_team_mean_midfield_score = df[df['away_team'] == away_team]['away_team_mean_midfield_score'].values[0]
away_team_mean_offense_score = df[df['away_team'] == away_team]['away_team_mean_offense_score'].values[0]

# add a row to knockout_stages
knockout_stages = knockout_stages.append({'date': date, 'home_team': home_team, 'away_team': away_team,
                                            'home_team_continent': home_team_continent, 'away_team_continent': away_team_continent,
                                            'tournament': tournament, 'city': city, 'country': country, 'neutral_location': neutral_location,
                                            'home_team_fifa_rank': home_team_rank, 'home_team_total_fifa_points': home_team_total_fifa_points,
                                            'home_team_goalkeeper_score': home_team_goalkeeper_score, 'home_team_mean_defense_score': home_team_mean_defense_score,
                                            'home_team_mean_midfield_score': home_team_mean_midfield_score, 'home_team_mean_offense_score': home_team_mean_offense_score,
                                            'away_team_fifa_rank': away_team_rank, 'away_team_total_fifa_points': away_team_total_fifa_points,
                                            'away_team_goalkeeper_score': away_team_goalkeeper_score, 'away_team_mean_defense_score': away_team_mean_defense_score,
                                            'away_team_mean_midfield_score': away_team_mean_midfield_score, 'away_team_mean_offense_score': away_team_mean_offense_score},
                                            ignore_index=True)

# # MATCH 6 : BRAZIL V. KOREA REPUBLIC ---------------------------------------------------------------------------------

# # -----------------------------------------------------------------------------------------------------------------------------

# # MATCH 7 : MOROCCO V. SPAIN ---------------------------------------------------------------------------------
date = '2022-12-06'
home_team = 'Morocco'
away_team = 'Spain'
home_team_continent = 'Africa'
away_team_continent = 'Europe'
tournament = 'FIFA World Cup'
city = 'Al Rayyan'
neutral_location = 'False'

# find rows where morocco is home team and take the home_team_fifa_ranking
home_team_rank = df[df['home_team'] == home_team]['home_team_fifa_rank'].values[0]
home_team_total_fifa_points = df[df['home_team'] == home_team]['home_team_total_fifa_points'].values[0]
home_team_goalkeeper_score = df[df['home_team'] == home_team]['home_team_goalkeeper_score'].values[0]
home_team_mean_defense_score = df[df['home_team'] == home_team]['home_team_mean_defense_score'].values[0]
home_team_mean_midfield_score = df[df['home_team'] == home_team]['home_team_mean_midfield_score'].values[0]
home_team_mean_offense_score = df[df['home_team'] == home_team]['home_team_mean_offense_score'].values[0]

# find rows where spain is away team and take the away_team_fifa_ranking
away_team_rank = df[df['away_team'] == away_team]['away_team_fifa_rank'].values[0]
away_team_total_fifa_points = df[df['away_team'] == away_team]['away_team_total_fifa_points'].values[0]
away_team_goalkeeper_score = df[df['away_team'] == away_team]['away_team_goalkeeper_score'].values[0]
away_team_mean_defense_score = df[df['away_team'] == away_team]['away_team_mean_defense_score'].values[0]
away_team_mean_midfield_score = df[df['away_team'] == away_team]['away_team_mean_midfield_score'].values[0]
away_team_mean_offense_score = df[df['away_team'] == away_team]['away_team_mean_offense_score'].values[0]

# add a row to knockout_stages
knockout_stages = knockout_stages.append({'date': date, 'home_team': home_team, 'away_team': away_team,
                                            'home_team_continent': home_team_continent, 'away_team_continent': away_team_continent,
                                            'tournament': tournament, 'city': city, 'country': country, 'neutral_location': neutral_location,
                                            'home_team_fifa_rank': home_team_rank, 'home_team_total_fifa_points': home_team_total_fifa_points,
                                            'home_team_goalkeeper_score': home_team_goalkeeper_score, 'home_team_mean_defense_score': home_team_mean_defense_score,
                                            'home_team_mean_midfield_score': home_team_mean_midfield_score, 'home_team_mean_offense_score': home_team_mean_offense_score,
                                            'away_team_fifa_rank': away_team_rank, 'away_team_total_fifa_points': away_team_total_fifa_points,
                                            'away_team_goalkeeper_score': away_team_goalkeeper_score, 'away_team_mean_defense_score': away_team_mean_defense_score,
                                            'away_team_mean_midfield_score': away_team_mean_midfield_score, 'away_team_mean_offense_score': away_team_mean_offense_score},
                                            ignore_index=True)

# # MATCH 7 : MOROCCO V. SPAIN ---------------------------------------------------------------------------------

# # -----------------------------------------------------------------------------------------------------------------------------

# # MATCH 8: PORTUGAL V. SWITZERLAND ---------------------------------------------------------------------------------
date = '2022-12-06'
home_team = 'Portugal'
away_team = 'Switzerland'
home_team_continent = 'Europe'
away_team_continent = 'Europe'
tournament = 'FIFA World Cup'
city = 'Lusail'

# find rows where portugal is home team and take the home_team_fifa_ranking
home_team_rank = df[df['home_team'] == home_team]['home_team_fifa_rank'].values[0]
home_team_total_fifa_points = df[df['home_team'] == home_team]['home_team_total_fifa_points'].values[0]
home_team_goalkeeper_score = df[df['home_team'] == home_team]['home_team_goalkeeper_score'].values[0]
home_team_mean_defense_score = df[df['home_team'] == home_team]['home_team_mean_defense_score'].values[0]
home_team_mean_midfield_score = df[df['home_team'] == home_team]['home_team_mean_midfield_score'].values[0]
home_team_mean_offense_score = df[df['home_team'] == home_team]['home_team_mean_offense_score'].values[0]

# find rows where switzerland is away team and take the away_team_fifa_ranking
away_team_rank = df[df['away_team'] == away_team]['away_team_fifa_rank'].values[0]
away_team_total_fifa_points = df[df['away_team'] == away_team]['away_team_total_fifa_points'].values[0]
away_team_goalkeeper_score = df[df['away_team'] == away_team]['away_team_goalkeeper_score'].values[0]
away_team_mean_defense_score = df[df['away_team'] == away_team]['away_team_mean_defense_score'].values[0]
away_team_mean_midfield_score = df[df['away_team'] == away_team]['away_team_mean_midfield_score'].values[0]
away_team_mean_offense_score = df[df['away_team'] == away_team]['away_team_mean_offense_score'].values[0]

# add a row to knockout_stages
knockout_stages = knockout_stages.append({'date': date, 'home_team': home_team, 'away_team': away_team,
                                            'home_team_continent': home_team_continent, 'away_team_continent': away_team_continent,
                                            'tournament': tournament, 'city': city, 'country': country, 'neutral_location': neutral_location,
                                            'home_team_fifa_rank': home_team_rank, 'home_team_total_fifa_points': home_team_total_fifa_points,
                                            'home_team_goalkeeper_score': home_team_goalkeeper_score, 'home_team_mean_defense_score': home_team_mean_defense_score,
                                            'home_team_mean_midfield_score': home_team_mean_midfield_score, 'home_team_mean_offense_score': home_team_mean_offense_score,
                                            'away_team_fifa_rank': away_team_rank, 'away_team_total_fifa_points': away_team_total_fifa_points,
                                            'away_team_goalkeeper_score': away_team_goalkeeper_score, 'away_team_mean_defense_score': away_team_mean_defense_score,
                                            'away_team_mean_midfield_score': away_team_mean_midfield_score, 'away_team_mean_offense_score': away_team_mean_offense_score},
                                            ignore_index=True)

# # MATCH 8 : PORTUGAL V. SWITZERLAND ---------------------------------------------------------------------------------

knockout_stages
# Out:
# /var/folders/cl/5v9cpvt93sjd32_z1w8t6b0c0000gn/T/ipykernel_78165/697206313.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   knockout_stages = knockout_stages.append({'date': date, 'home_team': home_team, 'away_team': away_team,
# /var/folders/cl/5v9cpvt93sjd32_z1w8t6b0c0000gn/T/ipykernel_78165/697206313.py:81: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   knockout_stages = knockout_stages.append({'date': date, 'home_team': home_team, 'away_team': away_team,
# /var/folders/cl/5v9cpvt93sjd32_z1w8t6b0c0000gn/T/ipykernel_78165/697206313.py:123: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   knockout_stages = knockout_stages.append({'date': date, 'home_team': home_team, 'away_team': away_team,
# ...

# %%
# save knockout_stages as csv
knockout_stages.to_csv('/Users/yenhann/Documents/MIT/15.095 Machine Learning/15095-project/data/knockout_stages.csv', index=False)

# %%
# load random forest pkl file
rf = pkl.load(open('/Users/yenhann/Documents/MIT/15.095 Machine Learning/15095-project/notebooks/rf_model.pkl', 'rb'))
# Out:
# /Users/yenhann/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator DecisionTreeClassifier from version 1.0.2 when using version 1.1.3. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /Users/yenhann/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator RandomForestClassifier from version 1.0.2 when using version 1.1.3. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
# display parameters of random forest
rf.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 42,
#  'verbose': 0,
#  'warm_start': False}

# %%
# run rf to predict knockout stage results
knockout_stages['home_team_win_probability'] = rf.predict_proba(knockout_stages[['home_team_fifa_rank', 'home_team_total_fifa_points',
